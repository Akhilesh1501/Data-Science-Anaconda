# %%
import pandas as pd

# %%
df = pd.DataFrame({"name":["xavier", "Urus", "Akhil", "Tim", "Tima", "sus"]})
df
# Out:
#      name
# 0  xavier
# 1    Urus
# 2   Akhil
# 3     Tim
# 4    Tima
# 5     sus

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["en_name"] =  le.fit_transform(df["name"])

# %%
df
# Out:
#      name  en_name
# 0  xavier        5
# 1    Urus        3
# 2   Akhil        0
# 3     Tim        1
# 4    Tima        2
# 5     sus        4

# %%
dataset = pd.read_csv("competition_clean.csv")
dataset.head(3)
# Out:
#    PassengerId  Pclass     Sex  SibSp  Parch Embarked Title GrpSize FareCat  \
# 0        892.0     NaN    male    0.0    NaN        Q    Mr    solo    0-10
# 1          NaN     NaN  female    1.0    0.0        S   Mrs     NaN    0-10
# 2          NaN     NaN    male    0.0    0.0        Q    Mr    solo    0-10
#
#   AgeCat
# 0    NaN
# 1  32-48
# 2  48-64

# %%
la = LabelEncoder()
la.fit(dataset["GrpSize"])
dataset["GrpSize"] = la.transform(dataset["GrpSize"])
dataset
# Out:
#      PassengerId  Pclass     Sex  SibSp  Parch Embarked       Title  GrpSize  \
# 0          892.0     NaN    male    0.0    NaN        Q          Mr        3
# 1            NaN     NaN  female    1.0    0.0        S         Mrs        4
# 2            NaN     NaN    male    0.0    0.0        Q          Mr        3
# 3          895.0     3.0    male    0.0    NaN        S          Mr        3
# 4          896.0     3.0  female    1.0    1.0        S         Mrs        1
# ..           ...     ...     ...    ...    ...      ...         ...      ...
# 413       1305.0     3.0    male    0.0    0.0        S          Mr        3
# 414       1306.0     1.0  female    0.0    0.0        C  Rare Title        3
# 415       1307.0     3.0    male    0.0    0.0        S          Mr        3
# 416       1308.0     3.0    male    0.0    0.0        S          Mr        3
# 417       1309.0     3.0    male    1.0    1.0      NaN         NaN        4
#
#     FareCat AgeCat
# 0      0-10    NaN
# ...
